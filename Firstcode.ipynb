# %% [markdown]
# <a href="https://colab.research.google.com/github/prodipsarkar03/Research-with-Machine-Learning-/blob/main/Firstcode.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello! I am Prodip Sarkar")
# Out:
# Hello! I am Prodip Sarkar
